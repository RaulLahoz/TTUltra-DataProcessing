# %% [markdown]
# ### Notebook $\alpha$
#
# Notebook para realizar un histograma de los diferentes valores obtenidos para $\alpha$. Tomaremos los diferemos valores de $\alpha$ obtenidos para cada una de nuestras mediciones y haremos un histograma demostrando la distribución de estos valores, los cuales esperamos que estén en el rango de 0 < |$\alpha$| < 1.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Diccionario con valores de alpha
alpha_ON = {
    "C60_8_CW": 0.5216,
    "C60_9_CW": 0.0396,
    "C60_12_CW": 0.1251,
    "C60_13_CW": 0.5910,
    "C60_15_CW": 0.7574,
    "C60_18_CW_1": 0.1570,
    "C60_18_CW_2": 0.2425,
    "C60_19_CW": 0.3698,
    "C60_23_CW": 0.9481,
    "C60_29_CW": 0.2986,
    "C60_30_CW": 0.4455,
    "C60_31_CW": 0.2055,
    "C60_32_CW": 0.1924,
    "C60_33_CW": 0.3648,
    "C60_34_CW": 0.2858,
    "C60_35_CW": 0.6240,
    "C60_36_CW": 0.2715,
    "C60_38_CW": 0.4433,
    "C60_39_CW": 0.3018,
    "C60_40_CW": 0.1664,
    "C60_41_CW": 0.0683,
    "C60_50_CW": 0.7435,
}

# %%
# Diccionario con valores de los errores de alpha
alpha_ON_err = {
    "C60_15_CW": 0.0165,
    "C60_18_CW_1": 0.0277,
    "C60_18_CW_2": 0.0235,
    "C60_19_CW": 0.0112,
    "C60_23_CW": 0.0428,
    "C60_29_CW": 0.0248,
    "C60_13_CW": 0.0079,
    "C60_12_CW": 0.0383,
    "C60_9_CW": 0.0131,
    "C60_8_CW": 0.0123,
}

# %%
# Número de bins
n_bins = 8  # Puedes cambiar este valor

# Tamaño de fuente
font_size = 16

# Extraer valores de alpha
alpha_values = list(alpha_ON.values())

# Crear el histograma
plt.figure(figsize=(6, 4))
counts, bins, patches = plt.hist(alpha_values, bins=n_bins, color='#A0A0A0', edgecolor='black', alpha=0.7)

# Calcular los centros de los bins y formatearlos con 2 decimales
bin_centers = (bins[:-1] + bins[1:]) / 2
bin_labels = [f"{center:.2f}" for center in bin_centers]

# Etiquetas y título con tamaño de fuente
plt.xlabel(r'$\alpha$ values', fontsize=font_size)
plt.ylabel("Frequency", fontsize=font_size)

# Ajustar etiquetas del eje X con los centros de los bins y rotarlos 45 grados
plt.xticks(bin_centers, bin_labels, fontsize=font_size, rotation=45)

# Ajustar el eje Y para que solo muestre números enteros
plt.yticks(np.arange(0, max(counts) + 1, 1), fontsize=font_size)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ### Notebook lifetime ($\tau$)
#
# Notebook para realizar un histograma de los diferentes valores obtenidos para $\tau$. Tomaremos los diferemos valores de $\tau_X$ obtenidos para cada una de nuestras mediciones y haremos un histograma demostrando la distribución de estos valores.

# %%
# Diccionario con valores del decay lifetime
tau_C60 = {
    "QD_8 (CW)": 5.10,
    "QD_9 (CW)": 5.32,
    "QD_12 (CW)": 4.52,
    "QD_13 (CW)": 5.46,
    "QD_15 (CW)": 6.20,
    "QD_18 (CW 1)": 9.38,
    "QD_18 (CW 2)": 7.20,
    "QD_19 (CW)": 5.91,
    "QD_20 (CW)": 3.60,
    "QD_22 (CW)": 9.16,
    "QD_23 (CW)": 7.78,
    "QD_24 (CW)": 5.14,
    "QD_25 (CW)": 5.59,
    "QD_26 (CW)": 7.62,
    "QD_29 (CW)": 3.80,
    "QD_30 (CW)": 16.41,
    "QD_31 (CW)": 26.37,
    "QD_32 (CW)": 27.00,
    "QD_33 (CW)": 23.80,
    "QD_34 (CW)": 22.80,
    "QD_35 (CW)": 7.20,
    "QD_36 (CW)": 14.49,
    "QD_37 (CW)": 15.50,
    "QD_38 (CW)": 21.44,
    "QD_39 (CW)": 17.38,
    "QD_40 (CW)": 15.49,
    "QD_41 (CW)": 20.96,
    "QD_42 (CW 1)": 7.61,
    "QD_42 (CW 2)": 6.20,
    "QD_42 (CW 3)": 9.84,
    "QD_42 (CW 4)": 17.09,
    "QD_43 (CW)": 12.79,
    "QD_44 (CW)": 16.90,
    "QD_45 (CW)": 12.11,
    "QD_47 (CW)": 15.72,
    "QD_49 (CW)": 17.57,
    "QD_50 (CW)": 19.37,
    "QD_51 (CW)": 13.79,
}

tau_CQDs = {
    "QD_12": 13.51,
    "QD_14": 14.57,
    "QD_15": 14.78,
    "QD_18": 16.25,
    "QD_19": 14.17,
    "QD_20": 14.78,
    "QD_21": 16.77,
    "QD_22": 18.47,
    "QD_24": 13.38,
    "QD_25": 14.63,
    "QD_26": 17.26,
    "QD_28": 13.92,
    "QD_29": 12.50,
    "QD_50": 14.79,
    "QD_51": 12.61,
    "QD_52": 18.73,
    "QD_53": 13.44,
    "QD_55": 22.68,
    "QD_56": 20.67,
    "QD_57": 13.54,
}

# %%
# Número de bins
n_bins = 20  # Puedes cambiar este valor
# Tamaño de fuente
font_size = 16

# Extraer valores de alpha
tau_list = list(tau_C60.values())

# Crear el histograma
plt.figure(figsize=(6, 4))
counts, bins, patches = plt.hist(tau_list, bins=n_bins, color="#C5CEFF", edgecolor='black', alpha=0.7)

# Calcular los centros de los bins y formatearlos con 2 decimales
bin_centers = (bins[:-1] + bins[1:]) / 2
bin_labels = [f"{center:.2f}" for center in bin_centers]

# Etiquetas y título con tamaño de fuente
plt.xlabel(r'$\tau$ values $C_{60}$ (ns)', fontsize=font_size)
plt.ylabel("Frequency", fontsize=font_size)

# Ajustar etiquetas del eje X para que vayan de 0 a 30 en saltos de 2
plt.xticks(np.arange(0, 28,2), fontsize=font_size, rotation=45)

# Ajustar el eje Y para que solo muestre números enteros
plt.yticks(np.arange(0, max(counts) + 1, 1), fontsize=font_size)

# Mostrar la gráfica
plt.show()

# %%
# Número de bins
n_bins = 10  # Puedes cambiar este valor
# Tamaño de fuente
font_size = 16

# Extraer valores de alpha
tau_list = list(tau_CQDs.values())

# Crear el histograma
plt.figure(figsize=(6, 4))
counts, bins, patches = plt.hist(tau_list, bins=n_bins, color="#FFC5C5", edgecolor='black', alpha=0.7)

# Calcular los centros de los bins y formatearlos con 2 decimales
bin_centers = (bins[:-1] + bins[1:]) / 2
bin_labels = [f"{center:.2f}" for center in bin_centers]

# Etiquetas y título con tamaño de fuente
plt.xlabel(r'$\tau$ values CQDs (ns)', fontsize=font_size)
plt.ylabel("Frequency", fontsize=font_size)

# Ajustar etiquetas del eje X para que vayan de 0 a 30 en saltos de 2
plt.xticks(np.arange(0, 28,2), fontsize=font_size, rotation=45)

# Ajustar el eje Y para que solo muestre números enteros
plt.yticks(np.arange(0, max(counts) + 1, 1), fontsize=font_size)

# Mostrar la gráfica
plt.show()
